# %% [markdown]
# # Final Project Proposal
# ## 1. Name/Members
# ### Project Name:
# Running Data Science
# ### Project Members:
# Suyash **lastname** and Jack Brandt
# ## 2. Dataset Description
# ### Source:
# Garmin's collection of all of Jack's data (that was collected by Jack's Garmin watch)
# ### Format:
# A folder full of folders primarily of csv's and json's
# ### Description of attributes/class info
# The following is a list of relevent attributes from the wellness data collected by the watch (obviously unimportant attributes have been left out for conciseness, like userId since all have the same)
# * totalKilocalories
#     * The total calories burned that day
# * activeKilocalories
#     * The calories burned during activity that day
# * totalSteps
#     * The total steps in a day
# * totalDistanceMeters
#     * Distance traveled that day in meters
# * StartTime
#     * The date for each instance
# * highlyActiveSeconds
#     * The time, in seconds, spent highly active
# * activeSeoncds
#     * The time, in seconds, spent active
# * vigorousIntensityMinutes
#     * The number of minutes of vigorous intensity
# * minHeartRate
#     * The lowest heart rate for that day
# * maxHeartRate
#     * The maximum heart rate for that day
# * currentDayRestingHeartRate
#     * The average heart rate at rest for that day
# * allDayStress__aggregatorList__averageStressLevel
#     * Measures the average stress level for the day
# * allDayStress__aggregatorList__averageStressLevelIntensity
#     * measures the average stress intensity for the day
# * allDayStress__aggregatorList__maxStressLevel
#     * Measures the max stress level for the day
# * allDayStress__aggregatorList__stressIntensityCount
#     * Counts stress intensity
# * allDayStress__aggregatorList__stressOffWristCount
#     * Counts time where wrist couldn't be measured by watch
#     * Or it measures time when it could
# * allDayStress__aggregatorList__stressTooActiveCount
#     * Measures time when stress level wasn't measured because an activity was under way
# * allDayStress__aggregatorList__totalStressCount
#     * measured total stress moments for the day
# * allDayStress__aggregatorList__totalStressIntensity
#     * Measures total stress intensity for the day
# * allDayStress__aggregatorList__stressDuration
#     * Measures total stress duration for the day
# * allDayStress__aggregatorList__restDuration
#     * Measures rest duration for the day
# * allDayStress__aggregatorList__activityDuration
#     * Measures activity duration for the day
# * allDayStress__aggregatorList__uncategorizedDuration
#     * Measures uncategorized time for the day
# * allDayStress__aggregatorList__totalDuration
#     * Measures total time measured for the day
# * allDayStress__aggregatorList__lowDuration
#     * Measures low duration stress moments for the day
# * allDayStress__aggregatorList__mediumDuration
#     * Measures medium duration stress for the day
# * allDayStress__aggregatorList__highDuration
#     * Measures high duration stress for the day
# * bodyBattery__chargedValue
#     * Measures how much the body was rested during the night
# * bodyBattery__drainedValue
#     * Measures how much the body was exerted during the day
# The following is a list of activity (i.e., running data) attributes. Activity and wellness data will be joined on date for the project. Again, obviously unrelated attributes (like device id) have been excluded.
# * activityType
#     * For are purposes will always be running
# * beginTimestamp
#     * An int that can be converted to a date, tells when run happened
# * duration
#     * How long the run lasted (in seconds)
# * distance
#     * How far the run was (maybe in feet)
# * elevationGain
#     * How much elevation was ascended total  for the run(probably also in feet)
#     * is not elevation_end - elevation_beginnning
# * elevationLoss
#     * How much elevation was descended total for the run
# * avgSpeed
#     * Average speed for the run (unknown unit, maybe km/minute)
# * maxSpeed
#     * The max speed for the run
# * avgHr
#     * The run's average heart rate
# * maxHr
#     * The run's max heart rate
# * avgRunCadence
#     * The average number of steps per minute for the run (rounded to nearest 1)
# * maxRunCadence
#     * The max running cadence (rounded to the nearest 1)
# * steps
#     * Number of steps on run
# * calories
#     * calories burned during run
# * bmrCalories
#     * the calories burned during the course of the run, that would have been burned anyway
# * avgStrideLength
#     * Average length of stride on run (in unknown unit)
# ## 3. Implementation/Technical Merit
# ###
